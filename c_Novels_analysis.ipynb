# %% [markdown]
# # Analysis of various novels
#
# In this notebook an analysis of various novels and one short poem will be conducted.
# There will be no additional commentary to the analysis, as no new methods have been introduced and reasoning is pretty straightforward at this point.
#
# Texts used in this analysis:
# - *"Do not go gentle into that good night"* by Dylan Thomas: [source](https://poets.org/poem/do-not-go-gentle-good-night)
# - *"Metamorphosis"* by Franz Kafka: [source](https://www.gutenberg.org/ebooks/5200)
# - *"The Trial"* by Franz Kafka: [source](https://www.gutenberg.org/ebooks/7849)
# - *"Amerika"* by Franz Kafka: [source](https://archive.org/stream/unset0000unse_o3y0/unset0000unse_o3y0_djvu.txt)
# - *"Demian"* by Hermann Hesse: [source](https://www.gutenberg.org/ebooks/74222)
# - *"1984"* by George Orwell: [source](https://archive.org/details/dli.ernet.240835)

# %%
import corpus_class as dc
import tokenedtext_class as prep
import freq_analysis as freq_a
import comp_analysis as comp_a
import result_visualisation as re_vis

import matplotlib.pyplot as plt
import os

# %%
novels_path = f"{os.getcwd()}\exemplar_texts\\novels_poems"
corpus_novels = dc.Corpus(novels_path)
# Out:
# Processing dylan_do_not_go.txt...
# Processing hesse_demian.txt...
# Processing kafka_amerika.txt...
# Processing kafka_metamorphosis.txt...
# Processing kafka_trial.txt...
# Processing orwell_1984.txt...
# Corpus novels_poems has been created

# %%
novels_info = corpus_novels.get_basic_info()
print(novels_info)
# Out:
# Basic info concerning novels_poems corpus:
# Number of text files: 6
# Number of distinct tokens: 17665
# Total number of words: 160199

# %%
novels_common = freq_a.create_bar_count(corpus_novels, n=25)
plt.show()

# %%
novels_wordcloud = freq_a.create_word_cloud(corpus_novels)
plt.show()

# %%
novels_csim = corpus_novels.cos_similarity_matrix()
novels_csim_fig = comp_a.plot_cos_similarity_heatmap(novels_csim)
plt.show()

# %%
novels_rand_toks = corpus_novels.get_random_tokens(n=10, seed=293)
novels_idf_tf = comp_a.get_tf_idf_batch(novels_rand_toks, corpus_novels)
novels_idf_tf_fig = comp_a.plot_tf_idf_matrix(novels_idf_tf)
plt.show()
